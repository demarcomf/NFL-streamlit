# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('nfl_dashboard_v3.csv')
df.head(10)
# Out:
#   away_team home_team  season_week predicted_winner actual_winner  \
# 0        TB       DAL            1               TB            TB
# 1       ATL       PHI            1              ATL           PHI
# 2       BUF       PIT            1              BUF           PIT
# 3       CAR       NYJ            1              CAR           CAR
# 4       CIN       MIN            1              MIN           CIN
# 5       DET        SF            1               SF            SF
# 6       HOU       JAX            1              JAX           HOU
# 7       IND       SEA            1              SEA           SEA
# 8       TEN       ARI            1              TEN           ARI
# 9       WAS       LAC            1              WAS           LAC
#
#   win_probability
# 0          80.39%
# 1          60.88%
# 2          74.08%
# 3          60.22%
# 4          66.92%
# 5          81.55%
# 6          66.40%
# 7          62.33%
# 8          61.79%
# 9          53.23%

# %%
df = df.fillna

# %%
df
# Out:
# <bound method DataFrame.fillna of     away_team home_team  season_week predicted_winner actual_winner  \
# 0          TB       DAL            1               TB            TB
# 1         ATL       PHI            1              ATL           PHI
# 2         BUF       PIT            1              BUF           PIT
# 3         CAR       NYJ            1              CAR           CAR
# 4         CIN       MIN            1              MIN           CIN
# ..        ...       ...          ...              ...           ...
# 142       LAC       MIN           10              LAC           LAC
# 143       DEN       PHI           10              DEN           DEN
# 144        LV        KC           10               KC            LV
# 145        SF        LA           10               LA            SF
# 146       ATL        NE           11               NE           ATL
#
#     win_probability
# 0            80.39%
# 1            60.88%
# 2            74.08%
# 3            60.22%
# ...

# %%
df.sort_values(['home_team', 'away_team'], ascending=[True, True])
